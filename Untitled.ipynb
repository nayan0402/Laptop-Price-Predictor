# %%
import pandas as pd

# %%
df=pd.read_csv("laptop_price.csv", encoding="latin-1")

# %%
df.drop("Product", axis=1, inplace=True)

# %%
df["ScreenResolution"]=df["ScreenResolution"].str.split(" ").apply(lambda x: x[-1])
df["Screen Width"]=df["ScreenResolution"].str.split("x").apply(lambda x: x[0])
df["Screen Hieght"]=df["ScreenResolution"].str.split("x").apply(lambda x: x[1])
df.drop("ScreenResolution", axis=1, inplace=True)

# %%
df["CPU Frequency"]=df["Cpu"].str.split(" ").apply(lambda x: x[-1])
df["CPU Model"]=df["Cpu"].str.split(" ").apply(lambda x: x[0])
df.drop("Cpu", axis=1, inplace=True)

# %%
df["Ram"]=df["Ram"].str[:-2]

# %%
df["Ram"]=df["Ram"].astype("int")
df["Screen Hieght"]=df["Screen Hieght"].astype("int")
df["Screen Width"]=df["Screen Width"].astype("int")
df["CPU Frequency"]=df["CPU Frequency"].str[:-3]
df["CPU Frequency"]=df["CPU Frequency"].astype("float")

# %%
df["MemoryAmount"] = df.Memory.str.split(" ").apply(lambda x: x[0])

# %%
def turn_memory_into_MB(value):
    if "GB" in value:
        return float(value[:value.find("GB")]) * 1024
    elif "TB" in value:
        return float(value[:value.find("TB")]) * 1024*1024

# %%
df["MemoryAmount"] = df["MemoryAmount"].apply(turn_memory_into_MB)
df.drop("Memory", axis=1, inplace=True)

# %%
df["Weight"] = df["Weight"].str[:-2]
df["Weight"] = df["Weight"].astype("float")

# %%
df["GPU Brand"] = df.Gpu.str.split(" ").apply(lambda x: x[0])

# %%
df = df.drop("Gpu", axis=1)

# %%
df = df.join(pd.get_dummies(df.OpSys))
df = df.drop("OpSys", axis=1)

# %%
cpu_categories = pd.get_dummies(df["CPU Model"])
cpu_categories.columns = [col + "_CPU" for col in cpu_categories.columns]

df = df.join(cpu_categories)
df = df.drop("CPU Model", axis=1)

# %%
gpu_categories = pd.get_dummies(df["GPU Brand"])
gpu_categories.columns = [col + "_GPU" for col in gpu_categories.columns]

df = df.join(gpu_categories)
df = df.drop("GPU Brand", axis=1)

# %%
df = df.join(pd.get_dummies(df.Company))
df = df.drop("Company", axis=1)
df = df.join(pd.get_dummies(df.TypeName))
df = df.drop("TypeName", axis=1)
df
# Out:
#       laptop_ID  Inches  Ram  Weight  Price_euros  Screen Width  \
# 0             1    13.3    8    1.37      1339.69          2560
# 1             2    13.3    8    1.34       898.94          1440
# 2             3    15.6    8    1.86       575.00          1920
# 3             4    15.4   16    1.83      2537.45          2880
# 4             5    13.3    8    1.37      1803.60          2560
# ...         ...     ...  ...     ...          ...           ...
# 1298       1316    14.0    4    1.80       638.00          1920
# 1299       1317    13.3   16    1.30      1499.00          3200
# 1300       1318    14.0    2    1.50       229.00          1366
# 1301       1319    15.6    6    2.19       764.00          1366
# 1302       1320    15.6    4    2.20       369.00          1366
#
#       Screen Hieght  CPU Frequency  MemoryAmount  Android  ...  Samsung  \
# 0              1600            2.3      131072.0    False  ...    False
# 1               900            1.8      131072.0    False  ...    False
# 2              1080            2.5      262144.0    False  ...    False
# 3              1800            2.7      524288.0    False  ...    False
# 4              1600            3.1      262144.0    False  ...    False
# ...             ...            ...           ...      ...  ...      ...
# 1298           1080            2.5      131072.0    False  ...    False
# 1299           1800            2.5      524288.0    False  ...    False
# 1300            768            1.6       65536.0    False  ...    False
# 1301            768            2.5     1048576.0    False  ...    False
# 1302            768            1.6      512000.0    False  ...    False
#
#       Toshiba   Vero  Xiaomi  2 in 1 Convertible  Gaming  Netbook  Notebook  \
# 0       False  False   False               False   False    False     False
# 1       False  False   False               False   False    False     False
# 2       False  False   False               False   False    False      True
# 3       False  False   False               False   False    False     False
# 4       False  False   False               False   False    False     False
# ...       ...    ...     ...                 ...     ...      ...       ...
# 1298    False  False   False                True   False    False     False
# 1299    False  False   False                True   False    False     False
# 1300    False  False   False               False   False    False      True
# 1301    False  False   False               False   False    False      True
# 1302    False  False   False               False   False    False      True
#
#       Ultrabook  Workstation
# 0          True        False
# 1          True        False
# 2         False        False
# 3          True        False
# 4          True        False
# ...         ...          ...
# 1298      False        False
# 1299      False        False
# 1300      False        False
# 1301      False        False
# 1302      False        False
#
# [1303 rows x 50 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 15))
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
target_correlations = df.corr()['Price_euros'].apply(abs).sort_values()

# %%
target_correlations
# Out:
# Xiaomi                0.000776
# Asus                  0.010376
# Mac OS X              0.015656
# Huawei                0.016851
# Windows 10 S          0.018312
# Samsung_CPU           0.018431
# ARM_GPU               0.018431
# Fujitsu               0.027135
# Lenovo                0.029007
# Samsung               0.034584
# Google                0.038086
# Android               0.038700
# Toshiba               0.040339
# HP                    0.041291
# Microsoft             0.047562
# Dell                  0.048509
# Chuwi                 0.055646
# LG                    0.067053
# laptop_ID             0.067830
# Inches                0.068197
# Vero                  0.071972
# 2 in 1 Convertible    0.072675
# Apple                 0.080688
# Mediacom              0.087161
# macOS                 0.089928
# Netbook               0.097572
# Chrome OS             0.118684
# MemoryAmount          0.125363
# Windows 10            0.137048
# Windows 7             0.152381
# Linux                 0.162060
# No OS                 0.177094
# MSI                   0.180100
# AMD_CPU               0.180111
# Intel_CPU             0.181127
# Intel_GPU             0.184205
# AMD_GPU               0.199415
# Acer                  0.208349
# Weight                0.210370
# Razer                 0.233756
# Workstation           0.249752
# Ultrabook             0.255658
# Nvidia_GPU            0.348797
# Gaming                0.375789
# CPU Frequency         0.430293
# Notebook              0.549248
# Screen Hieght         0.552809
# Screen Width          0.556529
# Ram                   0.743007
# Price_euros           1.000000
# Name: Price_euros, dtype: float64

# %%
selected_features = target_correlations[-21:].index
selected_features = list(selected_features)
selected_features
# Out:
# ['Windows 7',
#  'Linux',
#  'No OS',
#  'MSI',
#  'AMD_CPU',
#  'Intel_CPU',
#  'Intel_GPU',
#  'AMD_GPU',
#  'Acer',
#  'Weight',
#  'Razer',
#  'Workstation',
#  'Ultrabook',
#  'Nvidia_GPU',
#  'Gaming',
#  'CPU Frequency',
#  'Notebook',
#  'Screen Hieght',
#  'Screen Width',
#  'Ram',
#  'Price_euros']

# %%
#now we make a limited df with these featuers
limited_df=df[selected_features]

# %%
limited_df
# Out:
#       Windows 7  Linux  No OS    MSI  AMD_CPU  Intel_CPU  Intel_GPU  AMD_GPU  \
# 0         False  False  False  False    False       True       True    False
# 1         False  False  False  False    False       True       True    False
# 2         False  False   True  False    False       True       True    False
# 3         False  False  False  False    False       True      False     True
# 4         False  False  False  False    False       True       True    False
# ...         ...    ...    ...    ...      ...        ...        ...      ...
# 1298      False  False  False  False    False       True       True    False
# 1299      False  False  False  False    False       True       True    False
# 1300      False  False  False  False    False       True       True    False
# 1301      False  False  False  False    False       True      False     True
# 1302      False  False  False  False    False       True       True    False
#
#        Acer  Weight  ...  Workstation  Ultrabook  Nvidia_GPU  Gaming  \
# 0     False    1.37  ...        False       True       False   False
# 1     False    1.34  ...        False       True       False   False
# 2     False    1.86  ...        False      False       False   False
# 3     False    1.83  ...        False       True       False   False
# 4     False    1.37  ...        False       True       False   False
# ...     ...     ...  ...          ...        ...         ...     ...
# 1298  False    1.80  ...        False      False       False   False
# 1299  False    1.30  ...        False      False       False   False
# 1300  False    1.50  ...        False      False       False   False
# 1301  False    2.19  ...        False      False       False   False
# 1302  False    2.20  ...        False      False       False   False
#
#       CPU Frequency  Notebook  Screen Hieght  Screen Width  Ram  Price_euros
# 0               2.3     False           1600          2560    8      1339.69
# 1               1.8     False            900          1440    8       898.94
# 2               2.5      True           1080          1920    8       575.00
# 3               2.7     False           1800          2880   16      2537.45
# 4               3.1     False           1600          2560    8      1803.60
# ...             ...       ...            ...           ...  ...          ...
# 1298            2.5     False           1080          1920    4       638.00
# 1299            2.5     False           1800          3200   16      1499.00
# 1300            1.6      True            768          1366    2       229.00
# 1301            2.5      True            768          1366    6       764.00
# 1302            1.6      True            768          1366    4       369.00
#
# [1303 rows x 21 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

X, y = limited_df.drop("Price_euros", axis=1), limited_df["Price_euros"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
forest = RandomForestRegressor()

forest.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test_scaled, y_test)
# Out:
# 0.8080324193033079
